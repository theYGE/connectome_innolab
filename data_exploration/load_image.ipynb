# %%
import os
import numpy as np
import nibabel as nib

# %%
filepath = r"C:/Study_courses/2022_winter_LMU/sample_data/fMRI"
filename = os.path.join(filepath, "rfMRI.nii.gz")

# %%
img = nib.load(filename)

# %%
img.shape
# Out:
# (88, 88, 64, 490)

# %%
img.get_data_dtype()
# Out:
# dtype('<i2')

# %%
data = img.get_fdata()

# %%
data.shape
# Out:
# (88, 88, 64, 490)

# %%
type(data)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
plt.imshow(data[:,:,60,0])

# %%
plt.imshow(data[0,0,:,:])
